# %%
from rag_eval import VectorDatabaseBuilder

# VectorDatabaseBuilder 会自动读取项目根目录下的 config/application.yaml 与 model_roles.yaml，
# 完成以下流程：
#   1）加载并处理数据集（例如 CMRC2018）
#   2）生成样本并切分为 chunks
#   3）构建并持久化 Chroma 向量库
#   4）返回一个可直接用于 RAG 检索的 vector_manager 对象
#
# 用户不需要关心内部步骤，只需调用 invoke() 即可。

builder = VectorDatabaseBuilder()
vector_manager = builder.invoke()

print("向量库已构建完成，可以继续运行 RAG 与评估。")
# Out:
# [vector_builder] 样本不存在，先构建 samples：C:\Users\11694\Desktop\Work\codes\251208_RAG_ver0.2.0\rag-eval-scaffold\datasets\processed\cmrc2018_samples.json
# [cmrc2018.sampling] 生成样本：C:\Users\11694\Desktop\Work\codes\251208_RAG_ver0.2.0\rag-eval-scaffold\datasets\processed\cmrc2018_samples.json，共 10 条，splits=['dev']
# [vector_builder] 使用 samples 切割 chunks → C:\Users\11694\Desktop\Work\codes\251208_RAG_ver0.2.0\rag-eval-scaffold\datasets\processed\cmrc2018_chunks.jsonl
# [chunking] 完成切片：C:\Users\11694\Desktop\Work\codes\251208_RAG_ver0.2.0\rag-eval-scaffold\datasets\processed\cmrc2018_samples.json → C:\Users\11694\Desktop\Work\codes\251208_RAG_ver0.2.0\rag-eval-scaffold\datasets\processed\cmrc2018_chunks.jsonl，原始 chunk 数量（含重复）=24，去重后写入=7
# [vector_builder] 写入向量库（共 7 条 chunk），collection='cmrc2018_default'
# [vector_store_manager] 写入文档 1-7 / 7
# [vector_builder] 向量库构建完成
# 向量库已构建完成，可以继续运行 RAG 与评估。
